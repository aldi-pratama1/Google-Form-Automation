# %%
# !git clone https://github.com/aldi-pratama1/Google-Form-Automation.git
# Out:
# Cloning into 'Google-Form-Automation'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 39 (delta 22), reused 23 (delta 9), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
# %cd Google-Form-Automation
# Out:
# /content/Google-Form-Automation/Google-Form-Automation/Google-Form-Automation

# %%
# !ls
# Out:
#  Automasi_Kuota_Puspa.ipynb  'Google Automation_4.py'
#  Automasi_Kuota_Puspa.py      GoogleCollab_FormAutomation.ipynb
#  Dataset

# %%
# !pip install requests

# %%
# !python 'Google Automation_4.py'
#!python 'Automasi_Kuota_Puspa.py'
# Out:
# ['No' 'Email_Address' 'Nama_Lengkap' 'Nama_Kegiatan' 'Jenis_Kegiatan'
#  'tanggal_mulai' 'bulan_mulai' 'tahun_mulai' 'tanggal_selesai'
#  'bulan_selesai' 'tahun_selesai' 'Durasi_Pelaksanaan' 'Upload_Bukti']
